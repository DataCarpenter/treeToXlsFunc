# %%
#!pip install graphviz

# on max osx
#! brew install graphviz

# %%
import sklearn
import graphviz 
import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()

X = iris.data
y = iris.target
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

class_names = iris.target_names
feature_names = iris.target_names

# %%
clf = tree.DecisionTreeClassifier(max_depth=3)
clf = clf.fit(X_train, y_train)
dot_data = tree.export_graphviz(clf, out_file=None, 
                    feature_names=iris.feature_names,  
                    class_names=iris.target_names,  
                    filled=True, rounded=True,  
                    special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
from treeToXlsFunc import treeToXlsFunc
cla=treeToXlsFunc(iris.target_names, iris.feature_names)
cla.tree_to_if_function(clf)
# Out:
# '=IF(Table1[@[petal width (cm)]]<=0.800000011920929,"setosa",IF(Table1[@[petal width (cm)]]<=1.75,IF(Table1[@[petal length (cm)]]<=4.949999809265137,"versicolor","virginica"),IF(Table1[@[petal length (cm)]]<=4.850000381469727,"versicolor","virginica")))'
